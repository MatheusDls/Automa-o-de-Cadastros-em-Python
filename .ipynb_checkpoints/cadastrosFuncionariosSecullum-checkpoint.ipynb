# %%
#Codigo para obter a localização do mouse (X,Y)
# Atraso de 10 segundos
time.sleep(5)

# Captura a posição atual do mouse
x, y = pyautogui.position()
print(f"Posição do mouse: x={x}, y={y}")
# Out:
# Posição do mouse: x=730, y=666

# %%
#liberar porto CMD - "C:\Program Files\Google\Chrome\Application\chrome.exe" --remote-debugging-port=9222 --user-data-dir="C:/chrome-automation"

import pandas as pd
import pyautogui as py
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 

# Configurar opções para se conectar à instância já aberta do Chrome
chrome_options = Options()
chrome_options.debugger_address = "localhost:9222"  

# Conectar ao Chrome existente
navegador = webdriver.Chrome(options=chrome_options)

tabela = pd.read_excel("TOMBA.xlsx")
display(tabela)

# Pausa de 5 segundos para iniciar a automação
time.sleep(5)

# Incluir Funcionarios (+)
py.click(1763, 167)

# Iterar sobre as linhas do DataFrame
for i, folha in enumerate(tabela["FOLHA"][149:], start=149):  #TIAGO DOS SANTOS
    nome = tabela.loc[i, "NOME"]
    pis = tabela.loc[i, "PIS"]
    cpf = tabela.loc[i, "CPF"]
    admissao = tabela.loc[i, "ADMISSÃO"].strftime("%d/%m/%Y") # Converter 'admissao' para o formato de string 'dd/mm/yyyy'
    funcao = tabela.loc[i, "FUNÇÃO"]
    departamento = tabela.loc[i, "DEPARTAMENTO"]
    email = tabela.loc[i, "EMAIL"]

    # Preencher Nª FOLHA
    navegador.find_element(By.XPATH, '//*[@id="NumeroFolha"]').send_keys(str(folha))
    
    # Preencher Nome
    navegador.find_element(By.XPATH, '//*[@id="Nome"]').send_keys(nome)

    # Preencher Nª PIS/PASEP
    navegador.find_element(By.XPATH, '//*[@id="NumeroPis"]').send_keys(str(pis))
    
    # Preencher CPF
    navegador.find_element(By.XPATH, '//*[@id="Cpf"]').send_keys(str(cpf))
    
    # Preencher Nª IDENTIFICADOR
    navegador.find_element(By.XPATH, '//*[@id="NumeroIdentificador"]').send_keys(str(folha))
    time.sleep(1)
    
    # Selecionar EMPRESA
    navegador.find_element(By.XPATH, '//*[@id="EmpresaId"]').send_keys("DISTRIBUIDORA DE PRODUTOS ALIMENTICIOS SAO ROQUE LTDA-(03.705.630/0003-11)")
    navegador.find_element(By.XPATH, '//*[@id="EmpresaId"]').send_keys(Keys.ENTER)
    time.sleep(1)
    
    # Selecionar HORARIO
    navegador.find_element(By.XPATH, '//*[@id="HorarioId"]').send_keys("COMERCIAL")
    navegador.find_element(By.XPATH, '//*[@id="HorarioId"]').send_keys(Keys.ENTER)
    
    time.sleep(1)
    
    # Selecionar FUNÇÃO
    py.click(1394, 760)
    time.sleep(1)
    navegador.find_element(By.XPATH, '//*[@id="FuncaoId"]').send_keys(funcao)
    navegador.find_element(By.XPATH, '//*[@id="FuncaoId"]').send_keys(Keys.ENTER)
    
    time.sleep(1)
    
    # Selecionar DEPARTAMENTO
    py.click(x=1393, y=808)
    navegador.find_element(By.XPATH, '//*[@id="DepartamentoId"]').send_keys(departamento)
    navegador.find_element(By.XPATH, '//*[@id="DepartamentoId"]').send_keys(Keys.ENTER)
     
    # Inserir ADMISSÃO
    navegador.find_element(By.XPATH, '//*[@id="Admissao"]').send_keys(admissao)
    
    # Incluir Email
    py.click(505, 604)
    navegador.find_element(By.XPATH, '//*[@id="Email"]').send_keys(email if pd.notna(email) else "")
    
    # Salvar Cadastro
    navegador.find_element(By.XPATH, '//*[@id="btnSalvar"]').send_keys(Keys.ENTER)

    time.sleep(2)
 
    # # Fechar mensagem de cadastramento
    #py.click(730, 666)
    
    # Incluir novo cadastro
    py.click(1763, 165)
# Out:
#      FOLHA                                NOME          PIS             CPF  \
# 0     4197             ADAILTON MARQUES PRATES  12671993082  946.759.025-53
# 1     2354            ADENILDO SANTOS DA SILVA  16089081826  063.413.665-82
# 2     3613               ADONIRAN MOTA PEREIRA  16016904156  038.101.895-45
# 3     2368               ADRIANO SANTOS ARAUJO  15191716276  050.476.325-39
# 4      410           AILSON DOS ANJOS DE JESUS  12957117055  026.052.895-16
# ..     ...                                 ...          ...             ...
# 150   1043           WANDERSON DA SILVA SANTOS  16551029508  033.201.055-40
# 151   3715        WANELY TAUANE SILVA DE SOUSA  16675105915  090.962.095-40
# 152   4322  YASMIN VITORIA CAVALCANTI PEIXINHO  22019996919  861.669.435-80
# 153   4323          YSLANE DA SILVA DOS SANTOS  26751828703  075.219.535-25
# 154   1346         YURI KEVIN PEDREIRA SANTANA  14755126270  047.298.645-73
#
#       ADMISSÃO                  FUNÇÃO  \
# 0   2024-02-19        ASSIST LOGISTICA
# 1   2019-04-03         OP EMPILHADEIRA
# 2   2023-02-13  OP EMPILHADEIRA NIV II
# 3   2019-04-25    ANALISTA PREV PERDAS
# 4   2006-06-01              CONFERENTE
# ..         ...                     ...
# 150 2013-04-04               ARRUMADOR
# 151 2023-05-15        ATEND E COMERCIO
# 152 2024-04-01        ATEND E COMERCIO
# 153 2024-05-06        AUX CONTAS PAGAR
# 154 2014-04-07    ANALISTA DEP PESSOAL
#
#                                DEPARTAMENTO                             EMAIL
# 0                              Log. Noturna            amprates2015@gmail.com
# 1                               Log. Diurna         NILDOSANTTOS850@GMAIL.COM
# 2                              Log. Noturna          adoniranmota@hotmail.com
# 3    Setor Prevenção de Perdas (Inventário)  ENGMECATRONICO.ADRIANO@GMAIL.COM
# 4                               Log. Diurna          jesusailson377@gmail.com
# ..                                      ...                               ...
# 150                            Log. Noturna                               NaN
# 151                          Jovem Aprendiz        cavalcantiedna03@gmail.com
# 152                Jovem Aprendiz (Inativo)        laninhaasantos09@gmail.com
# 153                          Contas a Pagar            yurikevinfsa@gmail.com
# 154                            Dept Pessoal                               NaN
#
# [155 rows x 8 columns]
